# %% [markdown]
# ## Install CheMBL web service package

# %%
! pip install chembl_webresource_client
# Out:
# ...
#   Using cached chembl_webresource_client-0.10.7-py3-none-any.whl (55 kB)
# ...
#   Using cached requests_cache-0.7.5-py3-none-any.whl (39 kB)
# ...
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# ...
#   Using cached url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# ...
#   Using cached attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# ...
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python310\\Scripts\\chembl_act.exe' -> 'C:\\Python310\\Scripts\\chembl_act.exe.deleteme'

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Search coronavirus in target

# %%
# Target search for acetylcholinesterase
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 4   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 5   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# ...

# %% [markdown]
# ## Select and retrive data forHuman Acetylcholinesterase only

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# ##### retrieve only bioactivity data for coronavirus 3C-like proteinase (CHEMBL3927) that are reported as IC50 values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id  \
# 0                None        33969
# 1                None        37563
# 2                None        37565
# 3                None        38902
# 4                None        41170
# ...               ...          ...
# 8200             None     22970946
# 8201             None     22970947
# 8202             None     22986924
# 8203             None     22986925
# 8204             None     22986926
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL643384
# 1                                                    []    CHEMBL643384
# 2                                                    []    CHEMBL643384
# 3                                                    []    CHEMBL643384
# 4                                                    []    CHEMBL643384
# ...                                                 ...             ...
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# #### handling missing value

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#      activity_comment  activity_id  \
# 0                None        33969
# 1                None        37563
# 2                None        37565
# 3                None        38902
# 4                None        41170
# ...               ...          ...
# 8200             None     22970946
# 8201             None     22970947
# 8202             None     22986924
# 8203             None     22986925
# 8204             None     22986926
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL643384
# 1                                                    []    CHEMBL643384
# 2                                                    []    CHEMBL643384
# 3                                                    []    CHEMBL643384
# 4                                                    []    CHEMBL643384
# ...                                                 ...             ...
# ...

# %%
df2 = df2[df.canonical_smiles.notna()]
pd.set_option("display.max_columns", None)
df2
# Out:
# <ipython-input-17-5f52e773d32c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#      activity_comment  activity_id  \
# 0                None        33969
# 1                None        37563
# 2                None        37565
# 3                None        38902
# 4                None        41170
# ...               ...          ...
# 8200             None     22970946
# 8201             None     22970947
# 8202             None     22986924
# 8203             None     22986925
# 8204             None     22986926
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL643384
# 1                                                    []    CHEMBL643384
# 2                                                    []    CHEMBL643384
# 3                                                    []    CHEMBL643384
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 5664

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr.head(5)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        33969                  []    CHEMBL643384
# 1             None        37563                  []    CHEMBL643384
# 2             None        37565                  []    CHEMBL643384
# 3             None        38902                  []    CHEMBL643384
# 4             None        41170                  []    CHEMBL643384
#
#                                    assay_description assay_type  \
# 0  Inhibitory concentration against acetylcholine...          B
# 1  Inhibitory concentration against acetylcholine...          B
# 2  Inhibitory concentration against acetylcholine...          B
# 3  Inhibitory concentration against acetylcholine...          B
# 4  Inhibitory concentration against acetylcholine...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# ...

# %%
df2_nr.standard_value
# Out:
# 0         750.0
# 1         100.0
# 2       50000.0
# 3         300.0
# 4         800.0
#          ...
# 8195    10500.0
# 8196     1220.0
# 8197     1450.0
# 8202    28980.0
# 8203        6.4
# Name: standard_value, Length: 5664, dtype: object

# %% [markdown]
# #### create  molecule_chembl_id to a list

# %%
mol_cid = []
for i in df2_nr.molecule_chembl_id:    
      mol_cid.append(i)

# %% [markdown]
# #### create canonical_smiles to a list

# %%
canonical_smiles = []
for i in df2_nr.canonical_smiles:    
      canonical_smiles.append(i)

# %% [markdown]
# #### create standard_value to a list

# %%
standard_value = []
for i in df2_nr.standard_value:
      standard_value.append(i)

# %% [markdown]
# ### Labeling compounds as either being active, inactive or intermediate
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.

# %%
bioactivity_class = []
for i in df2_nr.standard_value:       
    if float(i) >= 10000:        
        bioactivity_class.append("inactive")
    elif float(i) <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %% [markdown]
# #### Combine the 4 lists into a dataframe

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 5659      CHEMBL4779440               Brc1ccc([N+]2=Cc3ccccc3CC2)cc1.[Br-]
# 5660       CHEMBL417799       C[n+]1cc2c3c(ccc2c2ccc4cc5c(cc4c21)OCO5)OCO3
# 5661        CHEMBL13045      COc1ccc2c(c[n+](C)c3c4cc5c(cc4ccc23)OCO5)c1OC
# 5662      CHEMBL3085398  C=CC(C)(C)c1cc([C@@H]2CC(=O)c3c(O)cc(O)c(CC=C(...
# 5663       CHEMBL253998       CC(C)=CCc1c(O)cc(O)c2c1O[C@H](c1ccccc1)CC2=O
#
#      bioactivity_class standard_value
# ...

# %% [markdown]
# ## Alternative method (Better way)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 8195      CHEMBL4779440               Brc1ccc([N+]2=Cc3ccccc3CC2)cc1.[Br-]
# 8196       CHEMBL417799       C[n+]1cc2c3c(ccc2c2ccc4cc5c(cc4c21)OCO5)OCO3
# 8197        CHEMBL13045      COc1ccc2c(c[n+](C)c3c4cc5c(cc4ccc23)OCO5)c1OC
# 8202      CHEMBL3085398  C=CC(C)(C)c1cc([C@@H]2CC(=O)c3c(O)cc(O)c(CC=C(...
# 8203       CHEMBL253998       CC(C)=CCc1c(O)cc(O)c2c1O[C@H](c1ccccc1)CC2=O
#
#      standard_value
# 0             750.0
# 1             100.0
# ...

# %%
df3.to_csv('bioactivity_data2.csv', index=False)

# %%
df4 = pd.read_csv('bioactivity_data2.csv')

# %%
df4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 5659      CHEMBL4779440               Brc1ccc([N+]2=Cc3ccccc3CC2)cc1.[Br-]
# 5660       CHEMBL417799       C[n+]1cc2c3c(ccc2c2ccc4cc5c(cc4c21)OCO5)OCO3
# 5661        CHEMBL13045      COc1ccc2c(c[n+](C)c3c4cc5c(cc4ccc23)OCO5)c1OC
# 5662      CHEMBL3085398  C=CC(C)(C)c1cc([C@@H]2CC(=O)c3c(O)cc(O)c(CC=C(...
# 5663       CHEMBL253998       CC(C)=CCc1c(O)cc(O)c2c1O[C@H](c1ccccc1)CC2=O
#
#       standard_value
# 0              750.0
# 1              100.0
# ...

# %%
bioactivity_class = pd.Series(bioactivity_class, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 5659      CHEMBL4779440               Brc1ccc([N+]2=Cc3ccccc3CC2)cc1.[Br-]
# 5660       CHEMBL417799       C[n+]1cc2c3c(ccc2c2ccc4cc5c(cc4c21)OCO5)OCO3
# 5661        CHEMBL13045      COc1ccc2c(c[n+](C)c3c4cc5c(cc4ccc23)OCO5)c1OC
# 5662      CHEMBL3085398  C=CC(C)(C)c1cc([C@@H]2CC(=O)c3c(O)cc(O)c(CC=C(...
# 5663       CHEMBL253998       CC(C)=CCc1c(O)cc(O)c2c1O[C@H](c1ccccc1)CC2=O
#
#       standard_value         class
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df4 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 5659      CHEMBL4779440               Brc1ccc([N+]2=Cc3ccccc3CC2)cc1.[Br-]
# 5660       CHEMBL417799       C[n+]1cc2c3c(ccc2c2ccc4cc5c(cc4c21)OCO5)OCO3
# 5661        CHEMBL13045      COc1ccc2c(c[n+](C)c3c4cc5c(cc4ccc23)OCO5)c1OC
# 5662      CHEMBL3085398  C=CC(C)(C)c1cc([C@@H]2CC(=O)c3c(O)cc(O)c(CC=C(...
# 5663       CHEMBL253998       CC(C)=CCc1c(O)cc(O)c2c1O[C@H](c1ccccc1)CC2=O
#
#      bioactivity_class standard_value
# ...

# %%
df4.to_csv('acetylcholinesterase_bioactivity_preprocessed_data.csv', index=False)
